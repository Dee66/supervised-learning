# %% [markdown]
# # AI Solutions Architect Portfolio
#
# **From Engineering Leadership to Production-Ready AI**
#
# ---
#
# **Profile**
#
# AI Solutions Architect with 15+ years in backend engineering, cloud-native systems, and technical leadership. I design and deliver robust, scalable and business-aligned AI solutions—bridging the gap between ML research and operational excellence.
#
# **Portfolio Focus**
# - Modular, interactive notebooks—each demonstrating a core supervised learning concept and its real-world system behavior.
# - Production scenarios: cyber security, drift, scaling, and failure analysis.
# - MLOps, CI/CD, and monitoring—woven into every demonstration.
# - Architect’s Notes: actionable insights on system stability, scaling, and business value.
#
# **Recent Delivery**
#
# End-to-end design and deployment of [CodeCraft AI](https://github.com/Dee66/CodeCraft-AI)—a full-stack, AWS-native generative AI platform.
# → [Implementation Checklist](https://github.com/Dee66/CodeCraft-AI/blob/main/docs/checklist.md)
#
# **Key Technologies Used**
# - **AWS Native:** SageMaker, Lambda, ECS (Fargate), S3, ECR, ALB, IAM, Secrets Manager, SSM, CloudWatch, VPC, KMS
# - **MLOps & Automation:** CI/CD with GitHub Actions, multi-stage Docker builds, automated retraining, pre-commit hooks, code linting (Ruff), vulnerability scanning
# - **AI/ML:** Hugging Face Transformers, FAISS (vector search), PEFT, RAG, PyTorch, scikit-learn
# - **Infrastructure as Code (IaC)** AWS CDK (Python) for reproducible, auditable deployments
# - **Security:** OIDC-based passwordless deployment, least-privilege IAM, automated secret rotation, private networking
# - **Observability:** Centralized logging, CloudWatch dashboards, structured logs, proactive alerting
# - **Testing:** Pytest, nbval (Jupyter), coverage, static type checking (mypy)
#
# ---
#
# <details>
# <summary>🧠 Architect’s Note: Why a Living Portfolio?</summary>
#
# This notebook series is structured as a living system, not a static CV. Each module demonstrates not just ML theory, but how architectural choices drive reliability, scalability, and business impact in production.
# </details>

# %% [markdown]
# ## Why AI Architecture?
#
# After 15+ years leading engineering teams, I’m ready to architect and deliver AI systems that drive real business value. My goal: to bridge deep engineering rigor with modern ML, and lead organizations through the next wave of AI transformation—without starting from scratch. I thrive at the intersection of system reliability, operational excellence, and innovative AI.
#
# **What I deliver**
# I bridge the gap between ML research and operational excellence, delivering systems that are robust, scalable, and aligned to business value.
#
# ---

# %%
from IPython.display import Image, display, Markdown
import os

# Brief introduction for context and narrative
display(Markdown("""
### CodeCraft AI: Production-Grade Architecture

This architecture illustrates how I designed for security, scalability, and rapid iteration in real-world AI systems.

To ground this portfolio in real-world delivery, here’s the architecture of CodeCraft AI—a full-stack, AWS-native generative AI platform I designed and deployed end-to-end. This system embodies the principles highlighted throughout these notebooks: modularity, security, scalability, and operational confidence.
"""))

# Resolve the path relative to the project root (one level up from notebooks)
img_path = os.path.join("..", "assets", "architecture.png")
img_exists = os.path.exists(img_path)

if img_exists:
    display(Image(filename=img_path, width=900))
else:
    display(Markdown(f"> ⚠️ **Architecture diagram not found:** `{img_path}`"))

display(Markdown("""
<details>
<summary>🧠 Architect’s Note: Why This Architecture?</summary>

Diagram generated with the Diagrams library for clarity, reproducibility, and operational confidence.
- **Layered, AWS-native**: Instantly communicates production-readiness and cloud fluency.
- **Flows and dependencies**: Clean, readable, and credible—no edge chaos.
</details>
"""))
# Out:
# ### CodeCraft AI: Production-Grade Architecture
#
# This architecture illustrates how I designed for security, scalability, and rapid iteration in real-world AI systems.
#
# To ground this portfolio in real-world delivery, here’s the architecture of CodeCraft AI—a full-stack, AWS-native generative AI platform I designed and deployed end-to-end. This system embodies the principles highlighted throughout these notebooks: modularity, security, scalability, and operational confidence.
# <details>
# <summary>🧠 Architect’s Note: Why This Architecture?</summary>
#
# Diagram generated with the Diagrams library for clarity, reproducibility, and operational confidence.
# - **Layered, AWS-native**: Instantly communicates production-readiness and cloud fluency.
# - **Flows and dependencies**: Clean, readable, and credible—no edge chaos.
# </details>

# %%
from IPython.display import display, Markdown

display(Markdown("""
## 📚 Portfolio Roadmap: From ML Foundations to Production Systems

| Notebook | Key Concepts | Production Insight |
|---|---|---|
| [**1. Foundations of Supervised Learning**](./02_supervised_learning_systems.ipynb) | Regression vs. Classification, Decision Boundaries | How problem framing shapes system design |
| [**2. Linear Regression: Cost & Optimization**](./03_cost_curve_and_gradient_intuition.ipynb) | Cost Curves, Gradients, Failure Modes | Why optimization stability matters for deployment |
| [**3. Feature Engineering & Scaling**](./04_cost_curve_and_gradient_intuition_part_2.ipynb) | Scaling, Cost Surfaces, Interactivity | How feature scaling impacts convergence and cost |
| [**4. Polynomial Regression & Regularization**](./05_polynomial_regression.ipynb) | _Model Complexity, Overfitting, Regularization_ | _Controlling complexity for robust, scalable ML_ |
| [**5. Classification in Depth**](./06_classification.ipynb) | _Logistic Regression, Decision Boundaries_ | _Mapping model outputs to business risk_ |
| [**6. Best Practices & Pitfalls**](./07_best_practice.ipynb) | _Failure Modes, Production Reflection_ | _Avoiding silent failures in real systems_ |
| [**7. Advanced Topics & MLOps**](./08_advanced.ipynb) | _Regularization Heatmaps, Threshold Tuning, MLOps Mapping_ | _Connecting ML insights to CI/CD and monitoring_ |
"""))

display(Markdown("""
## 🔎 System Behaviors & Failure Cases

Below are the key system behaviors and failure cases surfaced across this portfolio. Each notebook demonstrates how these risks are detected, mitigated, or designed around in production AI systems.

| Failure Mode / Behavior         | Example Impact                        | Addressed In Notebook(s)         | 🛡️ Risk Level |
|---------------------------------|---------------------------------------|----------------------------------|:------------:|
| Misclassification, boundary ambiguity | Incorrect predictions, business risk | 1. Foundations of Supervised Learning | ⚠️ |
| Divergence, slow convergence, local minima | Unstable/slow training, outages     | 2. Linear Regression: Cost & Optimization | ⚠️ |
| Poor scaling, skewed gradients  | Model fails to learn, hidden errors   | 3. Feature Engineering & Scaling | ⚠️ |
| Overfitting, high variance      | Poor generalization, unreliable output| 4. Polynomial Regression & Regularization | ⚠️ |
| Threshold effects, false positives/negatives | Business/operational risk           | 5. Classification in Depth       | ⚠️ |
| Silent drift, undetected errors | Model decay, silent failures          | 6. Best Practices & Pitfalls     | 🚨 |
| Retraining, deployment, monitoring, drift | Model staleness, unmonitored risk   | 7. Advanced Topics & MLOps       | 🚨 |

> ⚠️ = High risk if unaddressed &nbsp;&nbsp; 🚨 = Critical risk in production

---
"""))
# Out:
# ## 📚 Portfolio Roadmap: From ML Foundations to Production Systems
#
# | Notebook | Key Concepts | Production Insight |
# |---|---|---|
# | [**1. Foundations of Supervised Learning**](./02_supervised_learning_systems.ipynb) | Regression vs. Classification, Decision Boundaries | How problem framing shapes system design |
# | [**2. Linear Regression: Cost & Optimization**](./03_cost_curve_and_gradient_intuition.ipynb) | Cost Curves, Gradients, Failure Modes | Why optimization stability matters for deployment |
# | [**3. Feature Engineering & Scaling**](./04_cost_curve_and_gradient_intuition_part_2.ipynb) | Scaling, Cost Surfaces, Interactivity | How feature scaling impacts convergence and cost |
# | [**4. Polynomial Regression & Regularization**](./05_polynomial_regression.ipynb) | _Model Complexity, Overfitting, Regularization_ | _Controlling complexity for robust, scalable ML_ |
# ...

# %% [markdown]
# <details>
# <summary>🧠 Architect’s Note: Why This Architecture?</summary>
#
# This architecture is designed for operational resilience, security, and rapid iteration.
# - **Stateless containers** and **managed endpoints** ensure scalability and fast recovery.
# - **Automated CI/CD, secret rotation, and monitoring** reduce operational risk.
# - **Fine-grained IAM and private networking** enforce least-privilege and compliance.
# - Every component is observable, auditable, and ready for continuous improvement.
#
# </details>

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

display(Markdown("""
## 📚 Interactive Portfolio Roadmap

Explore each notebook to see how core ML concepts map to real-world system behavior, production risks, and architectural best practices.
"""))

roadmap = [
    {
        "title": "1. Foundations of Supervised Learning",
        "notebook": "./02_supervised_learning_systems.ipynb",
        "concepts": "Regression vs. Classification, Decision Boundaries",
        "insight": "How problem framing shapes system design",
        "system_behavior": "Misclassification, boundary ambiguity",
        "architect_note": "Framing the problem correctly is critical—missteps here cascade into downstream system instability and business risk.",
        "description": "Establishes the basics of supervised learning, showing how problem framing and data boundaries impact downstream system reliability."
    },
    {
        "title": "2. Linear Regression: Cost & Optimization",
        "notebook": "./03_cost_curve_and_gradient_intuition.ipynb",
        "concepts": "Cost Curves, Gradients, Failure Modes",
        "insight": "Why optimization stability matters for deployment",
        "system_behavior": "Divergence, slow convergence, local minima",
        "architect_note": "Optimization isn’t just math—unstable training leads to unpredictable production behavior and costly outages.",
        "description": "Explores cost functions and optimization, revealing how instability here can cause unpredictable failures in production ML systems."
    },
    {
        "title": "3. Feature Engineering & Scaling",
        "notebook": "./04_cost_curve_and_gradient_intuition_part_2.ipynb",
        "concepts": "Scaling, Cost Surfaces, Interactivity",
        "insight": "How feature scaling impacts convergence and cost",
        "system_behavior": "Poor scaling, slow learning, skewed gradients",
        "architect_note": "Feature scaling is a silent killer—bad scaling can make even the best models fail in production.",
        "description": "Demonstrates the impact of feature scaling on model convergence and cost, highlighting risks that often go undetected until production."
    },
    {
        "title": "4. Polynomial Regression & Regularization",
        "notebook": "./05_polynomial_regression.ipynb",
        "concepts": "Model Complexity, Overfitting, Regularization",
        "insight": "Controlling complexity for robust, scalable ML",
        "system_behavior": "Overfitting, high variance, poor generalization",
        "architect_note": "Regularization is your insurance policy—without it, models may look great in dev but fail in the wild.",
        "description": "Shows how model complexity and regularization affect generalization, and why controlling these is essential for robust, scalable AI."
    },
    {
        "title": "5. Classification in Depth",
        "notebook": "./06_classification.ipynb",
        "concepts": "Logistic Regression, Decision Boundaries",
        "insight": "Mapping model outputs to business risk",
        "system_behavior": "Threshold effects, false positives/negatives",
        "architect_note": "Every classification threshold is a business decision—get it wrong, and you risk real-world impact.",
        "description": "Dives into classification, decision boundaries, and thresholding, connecting model outputs directly to business risk."
    },
    {
        "title": "6. Best Practices & Pitfalls",
        "notebook": "./07_best_practice.ipynb",
        "concepts": "Failure Modes, Production Reflection",
        "insight": "Avoiding silent failures in real systems",
        "system_behavior": "Silent drift, undetected errors, monitoring gaps",
        "architect_note": "Best practices aren’t optional—production ML is unforgiving of shortcuts.",
        "description": "Surfaces common ML failure modes and best practices, focusing on how to avoid silent errors and ensure operational reliability."
    },
    {
        "title": "7. Advanced Topics & MLOps",
        "notebook": "./08_advanced.ipynb",
        "concepts": "Regularization Heatmaps, Threshold Tuning, MLOps Mapping",
        "insight": "Connecting ML insights to CI/CD and monitoring",
        "system_behavior": "Retraining, deployment, monitoring, drift",
        "architect_note": "MLOps is the backbone—without robust automation and monitoring, even great models become liabilities.",
        "description": "Connects advanced ML topics to MLOps, showing how automation, monitoring, and retraining keep models reliable in production."
    }
]

options = [(f"{entry['title']}: {entry['concepts']}", idx) for idx, entry in enumerate(roadmap)]
dropdown = widgets.Dropdown(
    options=options,
    description='Explore:',
    layout=widgets.Layout(width='95%')
)

output = widgets.Output()

def show_details(idx):
    entry = roadmap[idx]
    with output:
        clear_output()
        display(Markdown(
            f"""
<div style="border:1.5px solid #b0b0b0; border-radius:10px; padding:18px; margin-bottom:12px; background: #fafbfc;">
<h4 style="margin-top:0;margin-bottom:8px;">
    <a href="{entry['notebook']}" target="_blank">{entry['title']}</a>
</h4>
<p style="margin-bottom:10px;"><i>{entry['description']}</i></p>
<ul style="margin:0 0 8px 0;padding-left:18px;">
  <li><b>Key Concepts:</b> {entry['concepts']}</li>
  <li><b>Production Insight:</b> {entry['insight']}</li>
  <li><b>System Behavior:</b> {entry['system_behavior']}</li>
</ul>
<div style="margin-top:10px; padding:10px 14px; background:#eaf3ff; border-left:4px solid #2b4c7e;">
  <b>🧠 Architect’s Note:</b> {entry['architect_note']}
</div>
</div>
"""
        ))

dropdown.observe(lambda change: show_details(change['new']) if change['type'] == 'change' and change['name'] == 'value' else None, names='value')

display(dropdown)
show_details(0)
display(output)
# Out:
# ## 📚 Interactive Portfolio Roadmap
#
# Explore each notebook to see how core ML concepts map to real-world system behavior, production risks, and architectural best practices.
# Dropdown(description='Explore:', layout=Layout(width='95%'), options=(('1. Foundations of Supervised Learning:…
# Output()
